# %% [markdown]
# Importer la base de donnée avec ces 2 tutos (FR ou En)
# FR
# https://www.tresfacile.net/python-et-les-bases-de-donnees-sqlite3/
#
# EN
# https://likegeeks.com/python-sqlite3-tutorial/

# %%
import sqlite3 as sq3

# %%
conn = sq3.connect("./Fifa19.db") # Crée une connexion  vers la database. Dans notre cas la database est locale.
 # N.B : Si la 
conn?

# %%
cursor = conn.cursor()

# %%
cursor.execute("select*from fifa19")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-4-4eaeb0e66abc> in <module>
# ----> 1 cursor.execute("select*from fifa19")
#
# OperationalError: no such table: fifa19

# %% [markdown]
# Avant cette requête ne fonctionnait pas. On avait un message qui disait qu'on est limité.

# %%
import pandas as pd # J'ai besoin de pandas pour travailler avec des dataframe. Je l'importe
cursor.execute("select*from fifa19 limit 500") # J'utilise le cursor pour executer la requête SQL
split1 = pd.DataFrame(cursor.fetchall()) # Je peux récupérer le résultat avec la fonction fetchall() du cursor
split1 # J'affiche mon nouveau dataframe.
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-5-dafdd75f794d> in <module>
#       1 import pandas as pd # J'ai besoin de pandas pour travailler avec des dataframe. Je l'importe
# ----> 2 cursor.execute("select*from fifa19 limit 500") # J'utilise le cursor pour executer la requête SQL
#       3 split1 = pd.DataFrame(cursor.fetchall()) # Je peux récupérer le résultat avec la fonction fetchall() du cursor
#       4 split1 # J'affiche mon nouveau dataframe.
#
# OperationalError: no such table: fifa19

# %%
# pour la deuxième partie, je fais la même chose en économisant quelques lignes.
split2 = cursor.execute("select*from fifa19 limit 500 Offset 500")
split2

# %% [markdown]
# Maintenant je doit réunir mes deux tableaux pour n'en faire qu'un seul. Je pourrait donc commencer mes visualisation des données.

# %% [markdown]
# Je voulais montrer pourquoi on avait split la db en 2 (Car on était limité en taille)  mais on s'est rendu compte que maintenant on pouvait importer toute la base d'un coup.

# %%
import pandas as pd
cursor.execute("select*from fifa19")
dfTotal = pd.DataFrame(cursor.fetchall())
print(cursor.fetchall)
cursor.fetchall
# Out:
# <built-in method fetchall of sqlite3.Cursor object at 0x000001B96BBB6D50>
# <function Cursor.fetchall>

# %%
dfTotal
# Out:
#           0       1                   2   3   \
# 0          0  158023            L. Messi  31
# 1          1   20801   Cristiano Ronaldo  33
# 2          2  190871           Neymar Jr  26
# 3          3  193080              De Gea  27
# 4          4  192985        K. De Bruyne  27
# ...      ...     ...                 ...  ..
# 18202  18202  238813        J. Lundstram  19
# 18203  18203  243165  N. Christoffersson  19
# 18204  18204  241638           B. Worman  16
# 18205  18205  246268      D. Walker-Rice  17
# 18206  18206  246269           G. Nugent  16
#
#                                                    4          5   \
# 0      https://cdn.sofifa.org/players/4/19/158023.png  Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png   Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png     Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png      Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png    Belgium
# ...                                               ...        ...
# 18202  https://cdn.sofifa.org/players/4/19/238813.png    England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png     Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png    England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png    England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png    England
#
#                                         6   7   8                    9   ...  \
# 0      https://cdn.sofifa.org/flags/52.png  94  94         FC Barcelona  ...
# 1      https://cdn.sofifa.org/flags/38.png  94  94             Juventus  ...
# 2      https://cdn.sofifa.org/flags/54.png  92  93  Paris Saint-Germain  ...
# 3      https://cdn.sofifa.org/flags/45.png  91  93    Manchester United  ...
# 4       https://cdn.sofifa.org/flags/7.png  91  92      Manchester City  ...
# ...                                    ...  ..  ..                  ...  ...
# 18202  https://cdn.sofifa.org/flags/14.png  47  65      Crewe Alexandra  ...
# 18203  https://cdn.sofifa.org/flags/46.png  47  63       Trelleborgs FF  ...
# 18204  https://cdn.sofifa.org/flags/14.png  47  67     Cambridge United  ...
# 18205  https://cdn.sofifa.org/flags/14.png  47  66      Tranmere Rovers  ...
# 18206  https://cdn.sofifa.org/flags/14.png  46  66      Tranmere Rovers  ...
#
#        79  80  81  82  83  84  85  86  87       88
# 0      96  33  28  26   6  11  15  14   8  €226.5M
# 1      95  28  31  23   7  11  15  14  11  €127.1M
# 2      94  27  24  33   9   9  15  15  11  €228.1M
# 3      68  15  21  13  90  85  87  88  94  €138.6M
# 4      88  68  58  51  15  13   5  10  13  €196.4M
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..      ...
# 18202  45  40  48  47  10  13   7   8   9    €143K
# 18203  42  22  15  19  10   9   9   5  12    €113K
# 18204  41  32  13  11   6   5  10   6  13    €165K
# 18205  46  20  25  27  14   6  14   8   9    €143K
# 18206  43  40  43  50  10  15   9  12   9    €165K
#
# [18207 rows x 89 columns]

# %% [markdown]
# Je vais donc pouvoir travailler à visionner les données

# %%
import seaborn as sns
print(dfTotal.dtypes)
liste = dfTotal.dtypes
# Out:
# 0     object
# 1     object
# 2     object
# 3     object
# 4     object
#        ...
# 84    object
# 85    object
# 86    object
# 87    object
# 88    object
# Length: 89, dtype: object
# 0     object
# 1     object
# 2     object
# 3     object
# 4     object
#        ...
# 84    object
# 85    object
# 86    object
# 87    object
# 88    object
# Length: 89, dtype: object
